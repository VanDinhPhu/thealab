# %%
import requests

# %%
api_url = 'http://127.0.0.1:8000/return_json_update_database/product_pks/'
api_data = requests.post(api_url, data={'token': '42c2db83-e36f-4b8c-ae92-5ff2153bbc8c'})

# %%
api_data.json()
# Out:
# {'func': 'product_pks',
#  'variant_pks': ['232306376',
#   '232306377',
#   '232306378',
#   '232306379',
#   '232011233',
#   '232011234',
#   '232011235',
#   '232011236',
#   '232011237',
#   '232011238',
#   '232011239',
#   '232011240',
#   '231304471',
#   '231304472',
#   '225661470',
#   '225661468',
#   '225661466',
#   '225661464',
#   '225661322',
#   '225661323',
#   '225661324',
#   '225661325',
#   '225661316',
#   '225661317',
#   '225661318',
#   '225661319',
#   '224990101',
#   '224990102',
#   '224990103',
#   '224990104',
#   '224990067',
#   '224990068',
#   '224990069',
#   '224990070',
#   '224989994',
#   '224989995',
#   '224989996',
#   '224989997',
#   '224989967',
#   '224989968',
#   '224989969',
#   '224989970',
#   '224951771',
#   '224951772',
#   '224951773',
#   '224951774',
#   '224951747',
#   '224951748',
#   '224951749',
#   '224951750',
#   '224733788',
#   '224733789',
#   '224733790',
#   '224733791',
#   '224733792',
#   '224733793',
# ...

# %%
# def export_db_to_csv(): ###(chỉ chạy LOCAL - KO chạy với server)
#   ## Call api reset export_csv
#   api_url = 'http://127.0.0.1:8000/theshea_data/return_json_update_database/create_csv_file/'
#   requests.post(api_url, data={'token': '42c2db83-e36f-4b8c-ae92-5ff2153bbc8c'})
#   # sleep(5)
#   return
# export_db_to_csv()
